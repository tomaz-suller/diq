# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from typing import Iterable

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.axes import Axes

from sf_permits.config import logger, PROFILING_DATA_DIR

sns.set_theme()

# %%
metric_dicts = {}
for path in PROFILING_DATA_DIR.glob("*.json"):
    metric = path.stem
    logger.info("Loading metric {}", metric)
    with path.open() as f:
        metric_dicts[metric] = json.load(f)
# Out:
# 2024-11-27 06:13:42.926 | INFO     | __main__:<module>:4 - Loading metric duplication
# 2024-11-27 06:13:42.927 | INFO     | __main__:<module>:4 - Loading metric completeness
# 2024-11-27 06:13:42.927 | INFO     | __main__:<module>:4 - Loading metric correlation
# 2024-11-27 06:13:42.927 | INFO     | __main__:<module>:4 - Loading metric original_dtypes
# 2024-11-27 06:13:42.927 | INFO     | __main__:<module>:4 - Loading metric inferred_dtypes
# 2024-11-27 06:13:42.927 | INFO     | __main__:<module>:4 - Loading metric standard_deviation_outliers
# 2024-11-27 06:13:42.929 | INFO     | __main__:<module>:4 - Loading metric inter_quantile_outliers
# 2024-11-27 06:13:42.946 | INFO     | __main__:<module>:4 - Loading metric uniqueness
# 2024-11-27 06:13:42.946 | INFO     | __main__:<module>:4 - Loading metric distribution
# 2024-11-27 06:13:42.947 | INFO     | __main__:<module>:4 - Loading metric interestingness

# %%
def table_attribute_values(metric: dict) -> pd.Series:
    table = metric.get("table", None)
    attributes = metric["attributes"]
    if table is not None:
        attributes["table"] = table
    return pd.Series(attributes)

# %%
def barplot(metirc_dict, figsize=(4, 10)):
    fig, ax = plt.subplots(figsize=figsize)
    sns.barplot(
        table_attribute_values(metirc_dict).sort_values(),
        orient="h",
        ax=ax,
    )
    return fig, ax

# %% [markdown]
# ### Completeness

# %%
barplot(metric_dicts["completeness"])
# Out:
# (<Figure size 400x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# * Are missing values in the `Completed Date` due to lack of data or incomplete works?
# * Two very distinct patterns: variables mostly missing and mostly present

# %% [markdown]
# ### Correlation

# %%
correlation_df = pd.DataFrame(metric_dicts["correlation"]["table"])
correlation_df
# Out:
#                             Permit Type  Street Number      Unit  \
# Permit Type                    1.000000      -0.002281  0.031978
# Street Number                 -0.002281       1.000000 -0.040662
# Unit                           0.031978      -0.040662  1.000000
# Number of Existing Stories     0.057106      -0.218557  0.167038
# Number of Proposed Stories     0.055431      -0.215047  0.168811
# Estimated Cost                -0.120878      -0.011152 -0.009094
# Revised Cost                  -0.120083      -0.010828 -0.007559
# Existing Units                -0.003030      -0.054865  0.222569
# Proposed Units                -0.013665      -0.055468  0.227423
# Plansets                      -0.011480      -0.003298 -0.081970
# Existing Construction Type    -0.004265       0.228214 -0.217840
# Proposed Construction Type    -0.033203       0.224609 -0.219103
# Supervisor District           -0.049109      -0.131445 -0.027666
# Zipcode                       -0.012200       0.107763  0.003612
# Record ID                     -0.015621      -0.039808 -0.275457
#
#                             Number of Existing Stories  \
# Permit Type                                   0.057106
# Street Number                                -0.218557
# Unit                                          0.167038
# Number of Existing Stories                    1.000000
# Number of Proposed Stories                    0.997356
# Estimated Cost                                0.030248
# Revised Cost                                  0.039181
# Existing Units                                0.295527
# Proposed Units                                0.294521
# Plansets                                      0.009473
# Existing Construction Type                   -0.679218
# Proposed Construction Type                   -0.686347
# Supervisor District                          -0.169487
# Zipcode                                      -0.341470
# Record ID                                    -0.147271
#
#                             Number of Proposed Stories  Estimated Cost  \
# Permit Type                                   0.055431       -0.120878
# Street Number                                -0.215047       -0.011152
# Unit                                          0.168811       -0.009094
# Number of Existing Stories                    0.997356        0.030248
# Number of Proposed Stories                    1.000000        0.050336
# Estimated Cost                                0.050336        1.000000
# Revised Cost                                  0.049165        0.978798
# Existing Units                                0.294658        0.014161
# Proposed Units                                0.304492        0.070412
# Plansets                                      0.009547        0.001451
# Existing Construction Type                   -0.688179       -0.048703
# Proposed Construction Type                   -0.683090       -0.056787
# Supervisor District                          -0.168097        0.009876
# Zipcode                                      -0.342105       -0.010436
# Record ID                                    -0.147121        0.003439
#
#                             Revised Cost  Existing Units  Proposed Units  \
# Permit Type                    -0.120083       -0.003030       -0.013665
# Street Number                  -0.010828       -0.054865       -0.055468
# Unit                           -0.007559        0.222569        0.227423
# Number of Existing Stories      0.039181        0.295527        0.294521
# Number of Proposed Stories      0.049165        0.294658        0.304492
# Estimated Cost                  0.978798        0.014161        0.070412
# Revised Cost                    1.000000        0.015667        0.065279
# Existing Units                  0.015667        1.000000        0.994071
# Proposed Units                  0.065279        0.994071        1.000000
# Plansets                        0.001309        0.001243        0.001548
# Existing Construction Type     -0.057447       -0.272255       -0.275976
# Proposed Construction Type     -0.048473       -0.273619       -0.289255
# Supervisor District             0.007252       -0.045800       -0.040889
# Zipcode                        -0.007235       -0.131599       -0.137086
# Record ID                       0.004590       -0.020978       -0.018544
#
#                             Plansets  Existing Construction Type  \
# Permit Type                -0.011480                   -0.004265
# Street Number              -0.003298                    0.228214
# Unit                       -0.081970                   -0.217840
# Number of Existing Stories  0.009473                   -0.679218
# Number of Proposed Stories  0.009547                   -0.688179
# Estimated Cost              0.001451                   -0.048703
# Revised Cost                0.001309                   -0.057447
# Existing Units              0.001243                   -0.272255
# Proposed Units              0.001548                   -0.275976
# Plansets                    1.000000                   -0.013277
# Existing Construction Type -0.013277                    1.000000
# Proposed Construction Type -0.013005                    0.998985
# Supervisor District         0.001314                    0.146966
# Zipcode                    -0.005074                    0.389032
# Record ID                  -0.001823                    0.117591
#
#                             Proposed Construction Type  Supervisor District  \
# Permit Type                                  -0.033203            -0.049109
# Street Number                                 0.224609            -0.131445
# Unit                                         -0.219103            -0.027666
# Number of Existing Stories                   -0.686347            -0.169487
# Number of Proposed Stories                   -0.683090            -0.168097
# Estimated Cost                               -0.056787             0.009876
# Revised Cost                                 -0.048473             0.007252
# Existing Units                               -0.273619            -0.045800
# Proposed Units                               -0.289255            -0.040889
# Plansets                                     -0.013005             0.001314
# Existing Construction Type                    0.998985             0.146966
# Proposed Construction Type                    1.000000             0.143738
# Supervisor District                           0.143738             1.000000
# Zipcode                                       0.391524            -0.070138
# Record ID                                     0.117531             0.414130
#
#                              Zipcode  Record ID
# Permit Type                -0.012200  -0.015621
# Street Number               0.107763  -0.039808
# Unit                        0.003612  -0.275457
# Number of Existing Stories -0.341470  -0.147271
# Number of Proposed Stories -0.342105  -0.147121
# Estimated Cost             -0.010436   0.003439
# Revised Cost               -0.007235   0.004590
# Existing Units             -0.131599  -0.020978
# Proposed Units             -0.137086  -0.018544
# Plansets                   -0.005074  -0.001823
# Existing Construction Type  0.389032   0.117591
# Proposed Construction Type  0.391524   0.117531
# Supervisor District        -0.070138   0.414130
# Zipcode                     1.000000   0.017347
# Record ID                   0.017347   1.000000

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(
    correlation_df,
    mask=np.triu(np.ones_like(correlation_df, dtype=bool)),
    center=0,
    square=True,
    cmap="flare",
    annot=True,
    fmt=".2f",
    annot_kws={"fontsize": 8},
    ax=ax,
)
ax.grid(False)

# %% [markdown]
# * Might be interesting to look at pair plot between variables with high absolute correlation?

# %% [markdown]
# ### Duplication

# %%
barplot(metric_dicts["duplication"])
# Out:
# (<Figure size 400x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# * Why are there duplicated permit numbers?
# * Description is an interesting case: not completely unique but not completely different either

# %% [markdown]
# ### Data types

# %%
pd.DataFrame(
    (
        pd.Series(metric_dicts["original_dtypes"]["table"], name="original"),
        pd.Series(metric_dicts["inferred_dtypes"]["table"], name="inferred"),
    )
).T
# Out:
#                                        original inferred
# Permit Number                            object   string
# Permit Type                               int64    Int64
# Permit Type Definition                   object   string
# Permit Creation Date                     object   string
# Block                                    object   string
# Lot                                      object   string
# Street Number                             int64    Int64
# Street Number Suffix                     object   string
# Street Name                              object   string
# Street Suffix                            object   string
# Unit                                    float64    Int64
# Unit Suffix                              object   string
# Description                              object   string
# Current Status                           object   string
# Current Status Date                      object   string
# Filed Date                               object   string
# Issued Date                              object   string
# Completed Date                           object   string
# First Construction Document Date         object   string
# Structural Notification                  object   string
# Number of Existing Stories              float64  Float64
# Number of Proposed Stories              float64  Float64
# Voluntary Soft-Story Retrofit            object   string
# Fire Only Permit                         object   string
# Permit Expiration Date                   object   string
# Estimated Cost                          float64  Float64
# Revised Cost                            float64  Float64
# Existing Use                             object   string
# Existing Units                          float64  Float64
# Proposed Use                             object   string
# Proposed Units                          float64    Int64
# Plansets                                float64    Int64
# TIDF Compliance                          object   string
# Existing Construction Type              float64    Int64
# Existing Construction Type Description   object   string
# Proposed Construction Type              float64    Int64
# Proposed Construction Type Description   object   string
# Site Permit                              object   string
# Supervisor District                     float64    Int64
# Neighborhoods - Analysis Boundaries      object   string
# Zipcode                                 float64    Int64
# Location                                 object   string
# Record ID                                 int64    Int64

# %% [markdown]
# * Number of stories wasn't inferred as integer, so are there floating point numbers of stories?
# * ZIP code was encoded as `float` in original dataset, so we'll want to recode as string, possibly padding with zeros

# %% [markdown]
# ### Distribution

# %%
distribution_df = pd.DataFrame(metric_dicts["distribution"]["attributes"]).T.rename(
    columns={
        "50%": "med",
        "25%": "q1",
        "75%": "q3",
    }
)
distribution_df
# Out:
#                                count          mean           std  \
# Permit Type                 198900.0  7.522323e+00  1.457451e+00
# Street Number               198900.0  1.121729e+03  1.135769e+03
# Unit                         29479.0  7.851718e+01  3.269813e+02
# Number of Existing Stories  156116.0  5.705773e+00  8.613455e+00
# Number of Proposed Stories  156032.0  5.745043e+00  8.613284e+00
# Estimated Cost              160834.0  1.689554e+05  3.630386e+06
# Revised Cost                192834.0  1.328562e+05  3.584903e+06
# Existing Units              147362.0  1.566616e+01  7.447632e+01
# Proposed Units              147989.0  1.651095e+01  7.522044e+01
# Plansets                    161591.0  1.274650e+00  2.240735e+01
# Existing Construction Type  155534.0  4.072878e+00  1.585756e+00
# Proposed Construction Type  155738.0  4.089529e+00  1.578766e+00
# Supervisor District         197183.0  5.538403e+00  2.887041e+00
# Zipcode                     197184.0  9.411550e+04  9.270131e+00
# Record ID                   198900.0  1.162048e+12  4.918215e+11
#
#                                      min            q1           med  \
# Permit Type                 1.000000e+00  8.000000e+00  8.000000e+00
# Street Number               0.000000e+00  2.350000e+02  7.100000e+02
# Unit                        0.000000e+00  0.000000e+00  0.000000e+00
# Number of Existing Stories  0.000000e+00  2.000000e+00  3.000000e+00
# Number of Proposed Stories  0.000000e+00  2.000000e+00  3.000000e+00
# Estimated Cost              1.000000e+00  3.300000e+03  1.100000e+04
# Revised Cost                0.000000e+00  1.000000e+00  7.000000e+03
# Existing Units              0.000000e+00  1.000000e+00  1.000000e+00
# Proposed Units              0.000000e+00  1.000000e+00  2.000000e+00
# Plansets                    0.000000e+00  0.000000e+00  2.000000e+00
# Existing Construction Type  1.000000e+00  3.000000e+00  5.000000e+00
# Proposed Construction Type  1.000000e+00  3.000000e+00  5.000000e+00
# Supervisor District         1.000000e+00  3.000000e+00  6.000000e+00
# Zipcode                     9.410200e+04  9.410900e+04  9.411400e+04
# Record ID                   1.293532e+10  1.308567e+12  1.371840e+12
#
#                                       q3           max
# Permit Type                 8.000000e+00  8.000000e+00
# Street Number               1.700000e+03  8.400000e+03
# Unit                        1.000000e+00  6.004000e+03
# Number of Existing Stories  4.000000e+00  7.800000e+01
# Number of Proposed Stories  4.000000e+00  7.800000e+01
# Estimated Cost              3.500000e+04  5.379586e+08
# Revised Cost                2.870750e+04  7.805000e+08
# Existing Units              4.000000e+00  1.907000e+03
# Proposed Units              4.000000e+00  1.911000e+03
# Plansets                    2.000000e+00  9.000000e+03
# Existing Construction Type  5.000000e+00  5.000000e+00
# Proposed Construction Type  5.000000e+00  5.000000e+00
# Supervisor District         8.000000e+00  1.100000e+01
# Zipcode                     9.412200e+04  9.415800e+04
# Record ID                   1.435000e+12  1.498342e+12

# %%
fig, axes = plt.subplots(
    ncols=4, nrows=distribution_df.shape[0] // 4 + 1, figsize=(16, 16)
)
axes: Iterable[Axes] = axes.ravel()
for ax, (attribute, statistics) in zip(axes, distribution_df.iterrows()):
    inter_quntile_range = statistics["q3"] - statistics["q1"]
    statistics["whislo"] = np.max(
        [statistics["q1"] - 1.5 * inter_quntile_range, statistics["min"]]
    )
    statistics["whishi"] = np.min(
        [statistics["q3"] + 1.5 * inter_quntile_range, statistics["max"]]
    )
    statistics["fliers"] = [statistics["min"], statistics["max"]]
    statistics["label"] = attribute
    ax.bxp(
        [statistics],
        meanline=True,
    )

# %% [markdown]
# * There's basically only a single type of permit
# * Some outliers in costs, units and plansets; perhaps from the same tuple?
# * At least one `Record ID` equal to 0

# %% [markdown]
# ### Interestingness

# %%
barplot(metric_dicts["interestingness"], figsize=(8, 10))
# Out:
# (<Figure size 800x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Uniqueness

# %%
value_percentages = metric_dicts["uniqueness"]["attributes"]
fig, ax = plt.subplots(
    nrows=len(value_percentages),
    figsize=(5, 200),
    sharex=False,
    sharey=False,
)
axes: Iterable[Axes] = ax.ravel()
for ax, (attribute, attribute_percentages) in zip(axes, value_percentages.items()):
    sns.barplot(attribute_percentages, ax=ax, orient="h")
    ax.set_title(attribute)

# %% [markdown]
# * `Fire Only Permit`, `Voluntary Soft-Story Refit` and `Structural Notification` have a single value each (`Y`), likely implying missing as negative
# *
